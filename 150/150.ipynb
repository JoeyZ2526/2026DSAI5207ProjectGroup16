# %%
import random
from pathlib import Path

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from PIL import Image
from sklearn.metrics import (
    average_precision_score,
    f1_score,
    precision_score,
    recall_score,
)
from sklearn.model_selection import KFold, train_test_split
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms
import matplotlib.pyplot as plt
import seaborn as sns
import shutil
import datetime
import json
import glob

# =========================
# 0. 全局配置
# =========================
SEED = 42
TEST_RATIO = 0.15
N_SPLITS = 5
BATCH_SIZE = 32
LR = 1e-3
EPOCHS = 150
NUM_WORKERS = 0
PRINT_EVERY = 10
THRESHOLDS = np.arange(0.30, 0.71, 0.05)
SMOKE_TEST = False

BASE_DIR = Path.cwd()
CSV_PATH = BASE_DIR / "pokemon.csv"
IMG_DIR = BASE_DIR / "images"
FIG_DIR = BASE_DIR / "figures"
FIG_DIR.mkdir(exist_ok=True)
MODEL_DIR = BASE_DIR / "model"
MODEL_DIR.mkdir(exist_ok=True)
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

if SMOKE_TEST:
    EPOCHS = 3


# =========================
# 1. 工具函数
# =========================
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False


def build_transforms():
    train_transform = transforms.Compose([
        transforms.Resize((128, 128)),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(15),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ])

    eval_transform = transforms.Compose([
        transforms.Resize((128, 128)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ])
    return train_transform, eval_transform


def split_train_val_test(dataset, test_ratio, seed):
    indices = np.arange(len(dataset))
    train_val_indices, test_indices = train_test_split(
        indices,
        test_size=test_ratio,
        random_state=seed,
        shuffle=True,
    )

    train_val_indices = np.asarray(train_val_indices)
    test_indices = np.asarray(test_indices)

    assert len(set(train_val_indices).intersection(set(test_indices))) == 0, "train_val 和 test 发生重叠"
    assert len(train_val_indices) + len(test_indices) == len(dataset), "切分后样本总数不一致" 

    return train_val_indices, test_indices


def safe_mean_average_precision(labels, probs):
    ap_scores = []
    for class_idx in range(labels.shape[1]):
        y_true = labels[:, class_idx]
        if y_true.sum() == 0:
            continue
        ap_scores.append(average_precision_score(y_true, probs[:, class_idx]))
    return float(np.mean(ap_scores)) if ap_scores else 0.0


def compute_pos_weight(dataset, indices):
    label_matrix = dataset.label_matrix[indices]
    pos_count = label_matrix.sum(axis=0)
    neg_count = len(indices) - pos_count
    weights = neg_count / np.maximum(pos_count, 1.0)
    return torch.tensor(weights, dtype=torch.float32)


def compute_f1_metrics(probs, labels, threshold):
    preds = (probs >= threshold).astype(int)
    return {
        "macro_f1": float(f1_score(labels, preds, average="macro", zero_division=0)),
        "micro_f1": float(f1_score(labels, preds, average="micro", zero_division=0)),
    }

def compute_test_detail_metrics(probs, labels, threshold):
    preds = (probs >= threshold).astype(int)
    return {
        "macro_f1": float(f1_score(labels, preds, average="macro", zero_division=0)),
        "micro_f1": float(f1_score(labels, preds, average="micro", zero_division=0)),
        "precision": float(precision_score(labels, preds, average="macro", zero_division=0)),
        "recall": float(recall_score(labels, preds, average="macro", zero_division=0)),
        "class_f1": f1_score(labels, preds, average=None, zero_division=0).tolist(),
    }

def find_best_threshold(probs, labels, thresholds):
    best = {
        "threshold": float(thresholds[0]),
        "macro_f1": -1.0,
        "micro_f1": -1.0,
    }

    for threshold in thresholds:
        metrics = compute_f1_metrics(probs, labels, threshold)

        better_macro = metrics["macro_f1"] > best["macro_f1"] + 1e-12
        same_macro = abs(metrics["macro_f1"] - best["macro_f1"]) <= 1e-12
        better_micro = metrics["micro_f1"] > best["micro_f1"] + 1e-12

        if better_macro or (same_macro and better_micro):
            best = {
                "threshold": float(threshold),
                "macro_f1": metrics["macro_f1"],
                "micro_f1": metrics["micro_f1"],
            }

    return best


def evaluate(model, loader, device, criterion=None):
    model.eval()
    total_loss = 0.0
    total_samples = 0
    all_probs = []
    all_labels = []

    with torch.no_grad():
        for imgs, labels in loader:
            imgs = imgs.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)

            logits = model(imgs)
            if criterion is not None:
                loss = criterion(logits, labels)
                total_loss += loss.item() * imgs.size(0)
                total_samples += imgs.size(0)

            probs = torch.sigmoid(logits).cpu().numpy()
            all_probs.append(probs)
            all_labels.append(labels.cpu().numpy())

    probs = np.vstack(all_probs)
    labels = np.vstack(all_labels).astype(int)

    return {
        "loss": total_loss / max(total_samples, 1),
        "mAP": safe_mean_average_precision(labels, probs),
        "probs": probs,
        "labels": labels,
    }


def summarize_metric(values):
    values = np.asarray(values, dtype=np.float64)
    mean = float(values.mean())
    std = float(values.std(ddof=1)) if len(values) > 1 else 0.0
    return mean, std

# %%
# =========================
# 2. 数据集定义
# =========================
class PokemonDataset(Dataset):
    def __init__(self, csv_file, img_dir):
        self.csv_file = Path(csv_file)
        self.img_dir = Path(img_dir)
        self.df = pd.read_csv(self.csv_file)

        self.types = [
            "Grass", "Poison", "Fire", "Flying", "Water", "Bug", "Normal", "Electric",
            "Ground", "Fairy", "Fighting", "Psychic", "Rock", "Steel", "Ice", "Ghost",
            "Dragon", "Dark"
        ]
        self.type2idx = {t: i for i, t in enumerate(self.types)}
        self.label_matrix = self._build_label_matrix()

    def _build_label_matrix(self):
        label_matrix = np.zeros((len(self.df), len(self.types)), dtype=np.float32)
        for row_idx, row in self.df.iterrows():
            t1 = row["Type1"]
            t2 = row["Type2"]
            if t1 in self.type2idx:
                label_matrix[row_idx, self.type2idx[t1]] = 1.0
            if isinstance(t2, str) and t2 in self.type2idx:
                label_matrix[row_idx, self.type2idx[t2]] = 1.0
        return label_matrix

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        img_name = self.df.iloc[idx]["Name"].lower() + ".png"
        img_path = self.img_dir / img_name
        with Image.open(img_path) as img:
            image = img.convert("RGB")
        label = torch.from_numpy(self.label_matrix[idx].copy())
        return image, label


class PokemonSubsetDataset(Dataset):
    def __init__(self, base_dataset, indices, transform=None):
        self.base_dataset = base_dataset
        self.indices = np.asarray(indices)
        self.transform = transform

    def __len__(self):
        return len(self.indices)

    def __getitem__(self, idx):
        image, label = self.base_dataset[int(self.indices[idx])]
        if self.transform is not None:
            image = self.transform(image)
        return image, label.float()

# %%
# =========================
# 3. 模型定义
# =========================
class ResidualBlock(nn.Module):
    def __init__(self, in_c, out_c):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_c, out_c, 3, padding=1),
            nn.BatchNorm2d(out_c),
            nn.ReLU(),
            nn.Conv2d(out_c, out_c, 3, padding=1),
            nn.BatchNorm2d(out_c),
        )
        self.shortcut = nn.Sequential()
        if in_c != out_c:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_c, out_c, 1),
                nn.BatchNorm2d(out_c),
            )

    def forward(self, x):
        return F.relu(self.conv(x) + self.shortcut(x))


class PokemonModel(nn.Module):
    def __init__(self, use_res=False, pool_type="GAP", num_classes=18):
        super().__init__()

        def make_block(in_c, out_c):
            if use_res:
                return ResidualBlock(in_c, out_c)
            return nn.Sequential(
                nn.Conv2d(in_c, out_c, 3, padding=1),
                nn.BatchNorm2d(out_c),
                nn.ReLU(),
                nn.Conv2d(out_c, out_c, 3, padding=1),
                nn.BatchNorm2d(out_c),
                nn.ReLU(),
            )

        self.enc = nn.Sequential(
            make_block(3, 32), nn.MaxPool2d(2),
            make_block(32, 64), nn.MaxPool2d(2),
            make_block(64, 128), nn.MaxPool2d(2),
        )

        self.pool = nn.AdaptiveAvgPool2d(1) if pool_type == "GAP" else nn.AdaptiveMaxPool2d(1)
        self.fc = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(128, num_classes),
        )

    def forward(self, x):
        x = self.enc(x)
        x = self.pool(x).view(x.size(0), -1)
        return self.fc(x)

# %%
# =========================
# 4. 训练与评估主流程
# =========================
def build_loader(dataset, indices, transform, batch_size, shuffle):
    subset = PokemonSubsetDataset(dataset, indices, transform=transform)
    return DataLoader(
        subset,
        batch_size=batch_size,
        shuffle=shuffle,
        num_workers=NUM_WORKERS,
        pin_memory=torch.cuda.is_available(),
    )


def train_one_epoch(model, loader, optimizer, criterion, device):
    model.train()
    total_loss = 0.0
    total_samples = 0

    for imgs, labels in loader:
        imgs = imgs.to(device, non_blocking=True)
        labels = labels.to(device, non_blocking=True)

        optimizer.zero_grad()
        logits = model(imgs)
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()

        total_loss += loss.item() * imgs.size(0)
        total_samples += imgs.size(0)

    return total_loss / max(total_samples, 1)


def run_cv_experiment(config, dataset, train_val_indices, train_transform, eval_transform):
    print(f"\n{'=' * 24} {config['name']} | 5-Fold CV {'=' * 24}")
    kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=SEED)
    fold_records = []
    epoch_history = []   # 新增：存每个 epoch 的记录
    train_val_indices = np.asarray(train_val_indices)

    for fold_id, (train_pos, val_pos) in enumerate(kf.split(train_val_indices), start=1):
        fold_train_indices = train_val_indices[train_pos]
        fold_val_indices = train_val_indices[val_pos]

        train_loader = build_loader(dataset, fold_train_indices, train_transform, BATCH_SIZE, True)
        val_loader = build_loader(dataset, fold_val_indices, eval_transform, BATCH_SIZE, False)

        pos_weight = compute_pos_weight(dataset, fold_train_indices).to(DEVICE)
        model = PokemonModel(use_res=config["use_res"], pool_type=config["pool_type"]).to(DEVICE)
        optimizer = torch.optim.Adam(model.parameters(), lr=LR)
        criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)

        best_record = {
            "epoch": 1,
            "threshold": float(THRESHOLDS[0]),
            "val_loss": float("inf"),
            "macro_f1": -1.0,
            "micro_f1": -1.0,
            "mAP": 0.0,
        }

        print(f"Fold {fold_id}/{N_SPLITS}")
        for epoch in range(1, EPOCHS + 1):
            train_loss = train_one_epoch(model, train_loader, optimizer, criterion, DEVICE)
            val_result = evaluate(model, val_loader, DEVICE, criterion=criterion)
            threshold_result = find_best_threshold(val_result["probs"], val_result["labels"], THRESHOLDS)

            current_record = {
                "epoch": epoch,
                "threshold": threshold_result["threshold"],
                "val_loss": val_result["loss"],
                "macro_f1": threshold_result["macro_f1"],
                "micro_f1": threshold_result["micro_f1"],
                "mAP": val_result["mAP"],
            }

            # 新增：保存 epoch 历史
            epoch_history.append({
                "experiment": config["name"],
                "fold": fold_id,
                "epoch": epoch,
                "train_loss": float(train_loss),
                "val_loss": float(val_result["loss"]),
                "macro_f1": float(threshold_result["macro_f1"]),
                "micro_f1": float(threshold_result["micro_f1"]),
                "mAP": float(val_result["mAP"]),
                "threshold": float(threshold_result["threshold"]),
            })

            better_macro = current_record["macro_f1"] > best_record["macro_f1"] + 1e-12
            same_macro = abs(current_record["macro_f1"] - best_record["macro_f1"]) <= 1e-12
            lower_loss = current_record["val_loss"] < best_record["val_loss"] - 1e-12

            if better_macro or (same_macro and lower_loss):
                best_record.update(current_record)

            if epoch == 1 or epoch % PRINT_EVERY == 0 or epoch == EPOCHS:
                print(
                    f"Epoch {epoch:02d} | Train Loss: {train_loss:.4f} | "
                    f"Val Loss: {val_result['loss']:.4f} | "
                    f"Macro F1: {current_record['macro_f1']:.4f} | "
                    f"Micro F1: {current_record['micro_f1']:.4f} | "
                    f"mAP: {current_record['mAP']:.4f} | "
                    f"Thr: {current_record['threshold']:.2f}"
                )

        fold_summary = {
            "fold": fold_id,
            "best_epoch": int(best_record["epoch"]),
            "best_threshold": float(best_record["threshold"]),
            "val_loss": float(best_record["val_loss"]),
            "macro_f1": float(best_record["macro_f1"]),
            "micro_f1": float(best_record["micro_f1"]),
            "mAP": float(best_record["mAP"]),
        }
        fold_records.append(fold_summary)

        print(
            f"Fold {fold_id} Best | Epoch: {fold_summary['best_epoch']} | "
            f"Val Loss: {fold_summary['val_loss']:.4f} | "
            f"Macro F1: {fold_summary['macro_f1']:.4f} | "
            f"Micro F1: {fold_summary['micro_f1']:.4f} | "
            f"mAP: {fold_summary['mAP']:.4f} | "
            f"Thr: {fold_summary['best_threshold']:.2f}"
        )

    macro_mean, macro_std = summarize_metric([x["macro_f1"] for x in fold_records])
    micro_mean, micro_std = summarize_metric([x["micro_f1"] for x in fold_records])
    map_mean, map_std = summarize_metric([x["mAP"] for x in fold_records])
    best_epoch_final = int(np.median([x["best_epoch"] for x in fold_records]))
    best_threshold_final = float(np.median([x["best_threshold"] for x in fold_records]))

    cv_summary = {
        "name": config["name"],
        "cv_macro_mean": macro_mean,
        "cv_macro_std": macro_std,
        "cv_micro_mean": micro_mean,
        "cv_micro_std": micro_std,
        "cv_map_mean": map_mean,
        "cv_map_std": map_std,
        "best_epoch_final": best_epoch_final,
        "best_threshold_final": best_threshold_final,
        "fold_records": fold_records,
        "history_df": pd.DataFrame(epoch_history),   # 新增
    }

    print(
        f"\nCV Summary for {config['name']} | "
        f"Macro F1: {macro_mean:.4f} +/- {macro_std:.4f} | "
        f"Micro F1: {micro_mean:.4f} +/- {micro_std:.4f} | "
        f"mAP: {map_mean:.4f} +/- {map_std:.4f} | "
        f"Best Epoch(median): {best_epoch_final} | "
        f"Best Thr(median): {best_threshold_final:.2f}"
    )
    return cv_summary

def build_model_save_path(config):
    safe_name = config["name"].lower().replace(" + ", "_").replace(" ", "_")
    return MODEL_DIR / f"{safe_name}.pth"

def retrain_and_test(config, dataset, train_val_indices, test_indices, best_epoch, best_threshold, train_transform, eval_transform):
    print(f"\n{'-' * 20} Retrain on full train_val: {config['name']} {'-' * 20}")

    train_loader = build_loader(dataset, train_val_indices, train_transform, BATCH_SIZE, True)
    test_loader = build_loader(dataset, test_indices, eval_transform, BATCH_SIZE, False)

    pos_weight = compute_pos_weight(dataset, train_val_indices).to(DEVICE)
    model = PokemonModel(use_res=config["use_res"], pool_type=config["pool_type"]).to(DEVICE)
    optimizer = torch.optim.Adam(model.parameters(), lr=LR)
    criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)

    for epoch in range(1, best_epoch + 1):
        train_loss = train_one_epoch(model, train_loader, optimizer, criterion, DEVICE)
        if epoch == 1 or epoch % PRINT_EVERY == 0 or epoch == best_epoch:
            print(f"Epoch {epoch:02d} | Train Loss: {train_loss:.4f}")

    test_result = evaluate(model, test_loader, DEVICE, criterion=criterion)
    test_metrics = compute_test_detail_metrics(
        test_result["probs"],
        test_result["labels"],
        best_threshold,
    )

    model_path = build_model_save_path(config)

    checkpoint = {
        "model_state_dict": model.state_dict(),
        "config": config,
        "best_epoch": best_epoch,
        "best_threshold": best_threshold,
        "test_loss": float(test_result["loss"]),
        "test_macro_f1": float(test_metrics["macro_f1"]),
        "test_micro_f1": float(test_metrics["micro_f1"]),
        "test_precision": float(test_metrics["precision"]),
        "test_recall": float(test_metrics["recall"]),
        "test_class_f1": test_metrics["class_f1"],
        "test_mAP": float(test_result["mAP"]),
        "class_names": dataset.types,
    }
    torch.save(checkpoint, model_path)

    test_summary = {
        "test_loss": float(test_result["loss"]),
        "test_macro_f1": float(test_metrics["macro_f1"]),
        "test_micro_f1": float(test_metrics["micro_f1"]),
        "test_precision": float(test_metrics["precision"]),
        "test_recall": float(test_metrics["recall"]),
        "test_class_f1": test_metrics["class_f1"],
        "test_mAP": float(test_result["mAP"]),
        "model_path": str(model_path),
    }

    print(
        f"Test Result | Loss: {test_summary['test_loss']:.4f} | "
        f"Macro F1: {test_summary['test_macro_f1']:.4f} | "
        f"Micro F1: {test_summary['test_micro_f1']:.4f} | "
        f"Precision: {test_summary['test_precision']:.4f} | "
        f"Recall: {test_summary['test_recall']:.4f} | "
        f"mAP: {test_summary['test_mAP']:.4f} | "
        f"Thr: {best_threshold:.2f}"
    )
    print(f"Model saved to: {model_path}")

    return test_summary




# =========================
# 5. 主程序
# =========================
def main():
    set_seed(SEED)

    if not CSV_PATH.exists():
        raise FileNotFoundError(f"找不到 CSV 文件: {CSV_PATH}")
    if not IMG_DIR.exists():
        raise FileNotFoundError(f"找不到图片目录: {IMG_DIR}")

    print(f"Using device: {DEVICE}")
    print(f"Data root: {BASE_DIR}")
    print(f"CSV path : {CSV_PATH}")
    print(f"Image dir: {IMG_DIR}")
    print(f"SMOKE_TEST={SMOKE_TEST}, EPOCHS={EPOCHS}")

    dataset = PokemonDataset(CSV_PATH, IMG_DIR)
    class_names = dataset.types
    train_transform, eval_transform = build_transforms()
    train_val_indices, test_indices = split_train_val_test(dataset, TEST_RATIO, SEED)

    print(f"Total samples    : {len(dataset)}")
    print(f"Train/Val samples: {len(train_val_indices)}")
    print(f"Test samples     : {len(test_indices)}")

    experiments = [
        {"name": "Plain + GAP", "use_res": False, "pool_type": "GAP"},
        {"name": "Residual + GAP", "use_res": True, "pool_type": "GAP"},
        {"name": "Plain + GMP", "use_res": False, "pool_type": "GMP"},
    ]

    final_rows = []
    final_rows_raw = []
    all_histories = []

    for config in experiments:
        cv_summary = run_cv_experiment(
            config=config,
            dataset=dataset,
            train_val_indices=train_val_indices,
            train_transform=train_transform,
            eval_transform=eval_transform,
        )

        test_summary = retrain_and_test(
            config=config,
            dataset=dataset,
            train_val_indices=train_val_indices,
            test_indices=test_indices,
            best_epoch=cv_summary["best_epoch_final"],
            best_threshold=cv_summary["best_threshold_final"],
            train_transform=train_transform,
            eval_transform=eval_transform,
        )

        all_histories.append(cv_summary["history_df"])

        final_rows_raw.append({
            "Experiment": config["name"],
            "cv_macro_mean": cv_summary["cv_macro_mean"],
            "cv_macro_std": cv_summary["cv_macro_std"],
            "cv_micro_mean": cv_summary["cv_micro_mean"],
            "cv_micro_std": cv_summary["cv_micro_std"],
            "cv_map_mean": cv_summary["cv_map_mean"],
            "cv_map_std": cv_summary["cv_map_std"],
            "best_epoch": cv_summary["best_epoch_final"],
            "best_threshold": cv_summary["best_threshold_final"],
            "test_macro_f1": test_summary["test_macro_f1"],
            "test_micro_f1": test_summary["test_micro_f1"],
            "test_precision": test_summary["test_precision"],
            "test_recall": test_summary["test_recall"],
            "test_class_f1": test_summary["test_class_f1"],
            "test_mAP": test_summary["test_mAP"],
            "model_path": test_summary["model_path"],
        })

        final_rows.append({
            "Experiment": config["name"],
            "CV Macro F1": f"{cv_summary['cv_macro_mean']:.4f} +/- {cv_summary['cv_macro_std']:.4f}",
            "CV Micro F1": f"{cv_summary['cv_micro_mean']:.4f} +/- {cv_summary['cv_micro_std']:.4f}",
            "CV mAP": f"{cv_summary['cv_map_mean']:.4f} +/- {cv_summary['cv_map_std']:.4f}",
            "Best Epoch": cv_summary["best_epoch_final"],
            "Best Threshold": round(cv_summary["best_threshold_final"], 2),
            "Test Macro F1": round(test_summary["test_macro_f1"], 4),
            "Test Micro F1": round(test_summary["test_micro_f1"], 4),
            "Test Precision": round(test_summary["test_precision"], 4),
            "Test Recall": round(test_summary["test_recall"], 4),
            "Test mAP": round(test_summary["test_mAP"], 4),
        })

    summary_df = pd.DataFrame(final_rows)
    summary_raw_df = pd.DataFrame(final_rows_raw)
    history_df = pd.concat(all_histories, ignore_index=True)

    print(f"\n{'=' * 24} Final Summary {'=' * 24}")
    print(summary_df.to_string(index=False))

    return summary_df, summary_raw_df, history_df, class_names

summary_df, summary_raw_df, history_df, class_names = main()
# Out:
# Using device: cuda
# Data root: C:\Users\KangjieLU\Pokemon_Project
# CSV path : C:\Users\KangjieLU\Pokemon_Project\pokemon.csv
# Image dir: C:\Users\KangjieLU\Pokemon_Project\images
# SMOKE_TEST=False, EPOCHS=150
# Total samples    : 809
# Train/Val samples: 687
# Test samples     : 122
#
# ======================== Plain + GAP | 5-Fold CV ========================
# Fold 1/5
# Epoch 01 | Train Loss: 1.2690 | Val Loss: 1.2983 | Macro F1: 0.1504 | Micro F1: 0.1529 | mAP: 0.1680 | Thr: 0.30
# Epoch 10 | Train Loss: 1.1426 | Val Loss: 1.2400 | Macro F1: 0.2098 | Micro F1: 0.2172 | mAP: 0.2323 | Thr: 0.50
# Epoch 20 | Train Loss: 1.1055 | Val Loss: 1.2551 | Macro F1: 0.2172 | Micro F1: 0.1854 | mAP: 0.2250 | Thr: 0.45
# Epoch 30 | Train Loss: 1.0800 | Val Loss: 1.2026 | Macro F1: 0.2462 | Micro F1: 0.2819 | mAP: 0.2524 | Thr: 0.60
# Epoch 40 | Train Loss: 1.0645 | Val Loss: 1.2523 | Macro F1: 0.2075 | Micro F1: 0.1833 | mAP: 0.2585 | Thr: 0.35
# Epoch 50 | Train Loss: 1.0366 | Val Loss: 1.1860 | Macro F1: 0.2555 | Micro F1: 0.2590 | mAP: 0.2689 | Thr: 0.55
# Epoch 60 | Train Loss: 1.0101 | Val Loss: 1.1831 | Macro F1: 0.2697 | Micro F1: 0.2832 | mAP: 0.2829 | Thr: 0.60
# Epoch 70 | Train Loss: 1.0180 | Val Loss: 1.1741 | Macro F1: 0.2720 | Micro F1: 0.2652 | mAP: 0.2774 | Thr: 0.55
# Epoch 80 | Train Loss: 0.9693 | Val Loss: 1.1932 | Macro F1: 0.2536 | Micro F1: 0.2910 | mAP: 0.2874 | Thr: 0.60
# Epoch 90 | Train Loss: 0.9639 | Val Loss: 1.1773 | Macro F1: 0.2838 | Micro F1: 0.3064 | mAP: 0.2895 | Thr: 0.55
# Epoch 100 | Train Loss: 0.9573 | Val Loss: 1.4483 | Macro F1: 0.2408 | Micro F1: 0.1976 | mAP: 0.2771 | Thr: 0.30
# Epoch 110 | Train Loss: 0.9692 | Val Loss: 1.2310 | Macro F1: 0.2582 | Micro F1: 0.2764 | mAP: 0.3023 | Thr: 0.55
# Epoch 120 | Train Loss: 0.9215 | Val Loss: 1.2417 | Macro F1: 0.2695 | Micro F1: 0.2527 | mAP: 0.3007 | Thr: 0.45
# Epoch 130 | Train Loss: 0.8958 | Val Loss: 1.3420 | Macro F1: 0.2859 | Micro F1: 0.2682 | mAP: 0.3174 | Thr: 0.50
# Epoch 140 | Train Loss: 0.8798 | Val Loss: 1.2552 | Macro F1: 0.2698 | Micro F1: 0.2686 | mAP: 0.2932 | Thr: 0.60
# Epoch 150 | Train Loss: 0.8660 | Val Loss: 1.2639 | Macro F1: 0.2817 | Micro F1: 0.3018 | mAP: 0.2838 | Thr: 0.60
# Fold 1 Best | Epoch: 138 | Val Loss: 1.2425 | Macro F1: 0.3179 | Micro F1: 0.2975 | mAP: 0.3196 | Thr: 0.55
# Fold 2/5
# Epoch 01 | Train Loss: 1.2749 | Val Loss: 1.2325 | Macro F1: 0.1556 | Micro F1: 0.1604 | mAP: 0.1584 | Thr: 0.45
# Epoch 10 | Train Loss: 1.1816 | Val Loss: 1.1556 | Macro F1: 0.2023 | Micro F1: 0.2015 | mAP: 0.2168 | Thr: 0.50
# Epoch 20 | Train Loss: 1.1367 | Val Loss: 1.1198 | Macro F1: 0.2278 | Micro F1: 0.2286 | mAP: 0.2649 | Thr: 0.55
# Epoch 30 | Train Loss: 1.0937 | Val Loss: 1.0867 | Macro F1: 0.2533 | Micro F1: 0.2428 | mAP: 0.2685 | Thr: 0.50
# Epoch 40 | Train Loss: 1.0540 | Val Loss: 1.1186 | Macro F1: 0.2553 | Micro F1: 0.2523 | mAP: 0.2468 | Thr: 0.55
# Epoch 50 | Train Loss: 1.0345 | Val Loss: 1.1223 | Macro F1: 0.2700 | Micro F1: 0.2786 | mAP: 0.2671 | Thr: 0.55
# Epoch 60 | Train Loss: 1.0589 | Val Loss: 1.1241 | Macro F1: 0.2586 | Micro F1: 0.2540 | mAP: 0.2708 | Thr: 0.50
# Epoch 70 | Train Loss: 1.0107 | Val Loss: 1.1794 | Macro F1: 0.2552 | Micro F1: 0.2431 | mAP: 0.2671 | Thr: 0.50
# Epoch 80 | Train Loss: 0.9809 | Val Loss: 1.1474 | Macro F1: 0.2650 | Micro F1: 0.2561 | mAP: 0.2738 | Thr: 0.50
# Epoch 90 | Train Loss: 0.9670 | Val Loss: 1.1446 | Macro F1: 0.2483 | Micro F1: 0.2471 | mAP: 0.2656 | Thr: 0.50
# Epoch 100 | Train Loss: 0.9340 | Val Loss: 1.1420 | Macro F1: 0.2664 | Micro F1: 0.2989 | mAP: 0.2756 | Thr: 0.65
# Epoch 110 | Train Loss: 0.9423 | Val Loss: 1.1388 | Macro F1: 0.2794 | Micro F1: 0.2830 | mAP: 0.2927 | Thr: 0.55
# Epoch 120 | Train Loss: 0.8924 | Val Loss: 1.1817 | Macro F1: 0.2721 | Micro F1: 0.2759 | mAP: 0.2875 | Thr: 0.55
# Epoch 130 | Train Loss: 0.8908 | Val Loss: 1.2699 | Macro F1: 0.2649 | Micro F1: 0.2579 | mAP: 0.2809 | Thr: 0.50
# Epoch 140 | Train Loss: 0.8857 | Val Loss: 1.1699 | Macro F1: 0.2707 | Micro F1: 0.2725 | mAP: 0.2771 | Thr: 0.55
# Epoch 150 | Train Loss: 0.8285 | Val Loss: 1.1982 | Macro F1: 0.3019 | Micro F1: 0.3011 | mAP: 0.2854 | Thr: 0.55
# Fold 2 Best | Epoch: 150 | Val Loss: 1.1982 | Macro F1: 0.3019 | Micro F1: 0.3011 | mAP: 0.2854 | Thr: 0.55
# Fold 3/5
# Epoch 01 | Train Loss: 1.2765 | Val Loss: 1.3011 | Macro F1: 0.1660 | Micro F1: 0.1697 | mAP: 0.1681 | Thr: 0.45
# Epoch 10 | Train Loss: 1.1634 | Val Loss: 1.2852 | Macro F1: 0.1892 | Micro F1: 0.1818 | mAP: 0.1942 | Thr: 0.50
# Epoch 20 | Train Loss: 1.1039 | Val Loss: 1.3430 | Macro F1: 0.2047 | Micro F1: 0.2123 | mAP: 0.2001 | Thr: 0.50
# Epoch 30 | Train Loss: 1.0651 | Val Loss: 1.2631 | Macro F1: 0.2287 | Micro F1: 0.2394 | mAP: 0.2251 | Thr: 0.55
# Epoch 40 | Train Loss: 1.0615 | Val Loss: 1.2697 | Macro F1: 0.2340 | Micro F1: 0.2346 | mAP: 0.2387 | Thr: 0.55
# Epoch 50 | Train Loss: 1.0143 | Val Loss: 1.2526 | Macro F1: 0.2440 | Micro F1: 0.2489 | mAP: 0.2510 | Thr: 0.60
# Epoch 60 | Train Loss: 0.9730 | Val Loss: 1.2736 | Macro F1: 0.2598 | Micro F1: 0.2648 | mAP: 0.2458 | Thr: 0.55
# Epoch 70 | Train Loss: 0.9932 | Val Loss: 1.2540 | Macro F1: 0.2788 | Micro F1: 0.2822 | mAP: 0.2478 | Thr: 0.60
# Epoch 80 | Train Loss: 0.9714 | Val Loss: 1.4709 | Macro F1: 0.2490 | Micro F1: 0.2527 | mAP: 0.2714 | Thr: 0.55
# Epoch 90 | Train Loss: 0.9392 | Val Loss: 1.3536 | Macro F1: 0.2538 | Micro F1: 0.2480 | mAP: 0.2532 | Thr: 0.55
# Epoch 100 | Train Loss: 0.9132 | Val Loss: 1.4296 | Macro F1: 0.2671 | Micro F1: 0.2199 | mAP: 0.2665 | Thr: 0.40
# Epoch 110 | Train Loss: 0.9009 | Val Loss: 1.4977 | Macro F1: 0.2476 | Micro F1: 0.2210 | mAP: 0.2783 | Thr: 0.50
# Epoch 120 | Train Loss: 0.8915 | Val Loss: 1.4133 | Macro F1: 0.2909 | Micro F1: 0.3008 | mAP: 0.2770 | Thr: 0.65
# Epoch 130 | Train Loss: 0.8615 | Val Loss: 1.5060 | Macro F1: 0.2717 | Micro F1: 0.2320 | mAP: 0.2853 | Thr: 0.45
# Epoch 140 | Train Loss: 0.8586 | Val Loss: 1.3421 | Macro F1: 0.2951 | Micro F1: 0.3108 | mAP: 0.2847 | Thr: 0.70
# Epoch 150 | Train Loss: 0.8243 | Val Loss: 1.9550 | Macro F1: 0.1936 | Micro F1: 0.1796 | mAP: 0.2870 | Thr: 0.40
# Fold 3 Best | Epoch: 121 | Val Loss: 1.3411 | Macro F1: 0.3042 | Micro F1: 0.3165 | mAP: 0.2828 | Thr: 0.70
# Fold 4/5
# Epoch 01 | Train Loss: 1.2782 | Val Loss: 1.2301 | Macro F1: 0.1818 | Micro F1: 0.1970 | mAP: 0.1927 | Thr: 0.50
# Epoch 10 | Train Loss: 1.1536 | Val Loss: 1.1863 | Macro F1: 0.2421 | Micro F1: 0.2507 | mAP: 0.2460 | Thr: 0.50
# Epoch 20 | Train Loss: 1.1215 | Val Loss: 1.1630 | Macro F1: 0.2413 | Micro F1: 0.2225 | mAP: 0.2628 | Thr: 0.55
# Epoch 30 | Train Loss: 1.0971 | Val Loss: 1.1557 | Macro F1: 0.2603 | Micro F1: 0.2635 | mAP: 0.2693 | Thr: 0.55
# Epoch 40 | Train Loss: 1.0876 | Val Loss: 1.1344 | Macro F1: 0.2751 | Micro F1: 0.3109 | mAP: 0.2822 | Thr: 0.60
# Epoch 50 | Train Loss: 1.0726 | Val Loss: 1.2778 | Macro F1: 0.2297 | Micro F1: 0.2205 | mAP: 0.2737 | Thr: 0.45
# Epoch 60 | Train Loss: 1.0330 | Val Loss: 1.1266 | Macro F1: 0.2911 | Micro F1: 0.2791 | mAP: 0.2974 | Thr: 0.55
# Epoch 70 | Train Loss: 1.0377 | Val Loss: 1.1899 | Macro F1: 0.2974 | Micro F1: 0.2771 | mAP: 0.3004 | Thr: 0.60
# Epoch 80 | Train Loss: 0.9988 | Val Loss: 1.2128 | Macro F1: 0.2622 | Micro F1: 0.2183 | mAP: 0.3014 | Thr: 0.50
# Epoch 90 | Train Loss: 0.9726 | Val Loss: 1.1153 | Macro F1: 0.3240 | Micro F1: 0.3565 | mAP: 0.3222 | Thr: 0.65
# Epoch 100 | Train Loss: 0.9888 | Val Loss: 1.3216 | Macro F1: 0.2442 | Micro F1: 0.2433 | mAP: 0.3101 | Thr: 0.70
# Epoch 110 | Train Loss: 0.9460 | Val Loss: 1.1491 | Macro F1: 0.3080 | Micro F1: 0.3262 | mAP: 0.3090 | Thr: 0.60
# Epoch 120 | Train Loss: 0.8953 | Val Loss: 1.2463 | Macro F1: 0.2897 | Micro F1: 0.2702 | mAP: 0.3406 | Thr: 0.60
# Epoch 130 | Train Loss: 0.9018 | Val Loss: 1.1514 | Macro F1: 0.2967 | Micro F1: 0.2922 | mAP: 0.3034 | Thr: 0.55
# Epoch 140 | Train Loss: 0.9015 | Val Loss: 1.3971 | Macro F1: 0.2757 | Micro F1: 0.2229 | mAP: 0.3258 | Thr: 0.30
# Epoch 150 | Train Loss: 0.8762 | Val Loss: 1.1101 | Macro F1: 0.3284 | Micro F1: 0.3674 | mAP: 0.3498 | Thr: 0.70
# Fold 4 Best | Epoch: 148 | Val Loss: 1.1857 | Macro F1: 0.3379 | Micro F1: 0.3293 | mAP: 0.3512 | Thr: 0.60
# Fold 5/5
# Epoch 01 | Train Loss: 1.2692 | Val Loss: 1.2911 | Macro F1: 0.1794 | Micro F1: 0.2048 | mAP: 0.1669 | Thr: 0.50
# Epoch 10 | Train Loss: 1.1402 | Val Loss: 1.2783 | Macro F1: 0.2227 | Micro F1: 0.2404 | mAP: 0.2130 | Thr: 0.50
# Epoch 20 | Train Loss: 1.0990 | Val Loss: 1.2410 | Macro F1: 0.2376 | Micro F1: 0.2630 | mAP: 0.2401 | Thr: 0.60
# Epoch 30 | Train Loss: 1.0578 | Val Loss: 1.2315 | Macro F1: 0.2659 | Micro F1: 0.2845 | mAP: 0.2760 | Thr: 0.55
# Epoch 40 | Train Loss: 1.0371 | Val Loss: 1.2283 | Macro F1: 0.2706 | Micro F1: 0.2644 | mAP: 0.2613 | Thr: 0.50
# Epoch 50 | Train Loss: 0.9993 | Val Loss: 1.3146 | Macro F1: 0.2248 | Micro F1: 0.2332 | mAP: 0.2556 | Thr: 0.50
# Epoch 60 | Train Loss: 1.0062 | Val Loss: 1.9235 | Macro F1: 0.1711 | Micro F1: 0.1787 | mAP: 0.2648 | Thr: 0.45
# Epoch 70 | Train Loss: 0.9820 | Val Loss: 1.6426 | Macro F1: 0.1961 | Micro F1: 0.2167 | mAP: 0.2566 | Thr: 0.65
# Epoch 80 | Train Loss: 0.9536 | Val Loss: 1.3172 | Macro F1: 0.2689 | Micro F1: 0.2705 | mAP: 0.2650 | Thr: 0.60
# Epoch 90 | Train Loss: 0.9215 | Val Loss: 2.1762 | Macro F1: 0.1380 | Micro F1: 0.1716 | mAP: 0.2657 | Thr: 0.55
# Epoch 100 | Train Loss: 0.9104 | Val Loss: 1.3304 | Macro F1: 0.2895 | Micro F1: 0.3097 | mAP: 0.2824 | Thr: 0.55
# Epoch 110 | Train Loss: 0.8680 | Val Loss: 1.4995 | Macro F1: 0.2426 | Micro F1: 0.2399 | mAP: 0.2740 | Thr: 0.45
# Epoch 120 | Train Loss: 0.9112 | Val Loss: 1.4676 | Macro F1: 0.2674 | Micro F1: 0.3046 | mAP: 0.2871 | Thr: 0.65
# Epoch 130 | Train Loss: 0.8601 | Val Loss: 1.4807 | Macro F1: 0.2449 | Micro F1: 0.2171 | mAP: 0.2772 | Thr: 0.35
# Epoch 140 | Train Loss: 0.8013 | Val Loss: 1.4633 | Macro F1: 0.2650 | Micro F1: 0.2712 | mAP: 0.2844 | Thr: 0.45
# Epoch 150 | Train Loss: 0.7921 | Val Loss: 1.7107 | Macro F1: 0.2448 | Micro F1: 0.2789 | mAP: 0.2880 | Thr: 0.60
# Fold 5 Best | Epoch: 141 | Val Loss: 1.4634 | Macro F1: 0.3182 | Micro F1: 0.3501 | mAP: 0.2956 | Thr: 0.60
#
# CV Summary for Plain + GAP | Macro F1: 0.3160 +/- 0.0144 | Micro F1: 0.3189 +/- 0.0216 | mAP: 0.3069 +/- 0.0287 | Best Epoch(median): 141 | Best Thr(median): 0.60
#
# -------------------- Retrain on full train_val: Plain + GAP --------------------
# Epoch 01 | Train Loss: 1.2696
# Epoch 10 | Train Loss: 1.1487
# Epoch 20 | Train Loss: 1.1038
# Epoch 30 | Train Loss: 1.0681
# Epoch 40 | Train Loss: 1.0508
# Epoch 50 | Train Loss: 1.0160
# Epoch 60 | Train Loss: 0.9881
# Epoch 70 | Train Loss: 0.9563
# Epoch 80 | Train Loss: 0.9648
# Epoch 90 | Train Loss: 0.9236
# Epoch 100 | Train Loss: 0.8925
# Epoch 110 | Train Loss: 0.8486
# Epoch 120 | Train Loss: 0.8451
# Epoch 130 | Train Loss: 0.7891
# Epoch 140 | Train Loss: 0.7741
# Epoch 141 | Train Loss: 0.7732
# Test Result | Loss: 1.2818 | Macro F1: 0.2845 | Micro F1: 0.2810 | Precision: 0.2518 | Recall: 0.3903 | mAP: 0.2790 | Thr: 0.60
# Model saved to: C:\Users\KangjieLU\Pokemon_Project\model\plain_gap.pth
#
# ======================== Residual + GAP | 5-Fold CV ========================
# Fold 1/5
# Epoch 01 | Train Loss: 1.2920 | Val Loss: 1.2679 | Macro F1: 0.1594 | Micro F1: 0.1694 | mAP: 0.1889 | Thr: 0.45
# Epoch 10 | Train Loss: 1.1424 | Val Loss: 1.2013 | Macro F1: 0.2142 | Micro F1: 0.2287 | mAP: 0.2558 | Thr: 0.60
# Epoch 20 | Train Loss: 1.0806 | Val Loss: 1.1493 | Macro F1: 0.2678 | Micro F1: 0.2779 | mAP: 0.2791 | Thr: 0.55
# Epoch 30 | Train Loss: 1.0328 | Val Loss: 1.1672 | Macro F1: 0.2762 | Micro F1: 0.2957 | mAP: 0.3023 | Thr: 0.60
# Epoch 40 | Train Loss: 1.0099 | Val Loss: 1.2828 | Macro F1: 0.2317 | Micro F1: 0.2104 | mAP: 0.3112 | Thr: 0.55
# Epoch 50 | Train Loss: 1.0003 | Val Loss: 1.5501 | Macro F1: 0.2233 | Micro F1: 0.1964 | mAP: 0.2751 | Thr: 0.45
# Epoch 60 | Train Loss: 0.9587 | Val Loss: 1.2150 | Macro F1: 0.2746 | Micro F1: 0.2720 | mAP: 0.3058 | Thr: 0.55
# Epoch 70 | Train Loss: 0.9238 | Val Loss: 1.2222 | Macro F1: 0.3045 | Micro F1: 0.3235 | mAP: 0.3124 | Thr: 0.55
# Epoch 80 | Train Loss: 0.8863 | Val Loss: 1.3147 | Macro F1: 0.2850 | Micro F1: 0.2909 | mAP: 0.3225 | Thr: 0.55
# Epoch 90 | Train Loss: 0.9054 | Val Loss: 1.2756 | Macro F1: 0.2821 | Micro F1: 0.3018 | mAP: 0.3011 | Thr: 0.65
# Epoch 100 | Train Loss: 0.8410 | Val Loss: 1.2746 | Macro F1: 0.3043 | Micro F1: 0.2797 | mAP: 0.3108 | Thr: 0.50
# Epoch 110 | Train Loss: 0.8425 | Val Loss: 1.3015 | Macro F1: 0.2839 | Micro F1: 0.3077 | mAP: 0.3268 | Thr: 0.60
# Epoch 120 | Train Loss: 0.7575 | Val Loss: 1.3959 | Macro F1: 0.2867 | Micro F1: 0.2390 | mAP: 0.3222 | Thr: 0.55
# Epoch 130 | Train Loss: 0.7552 | Val Loss: 1.6777 | Macro F1: 0.2623 | Micro F1: 0.1935 | mAP: 0.3262 | Thr: 0.30
# Epoch 140 | Train Loss: 0.7140 | Val Loss: 1.5028 | Macro F1: 0.2963 | Micro F1: 0.2539 | mAP: 0.3481 | Thr: 0.45
# Epoch 150 | Train Loss: 0.7277 | Val Loss: 2.6992 | Macro F1: 0.1885 | Micro F1: 0.2068 | mAP: 0.3096 | Thr: 0.30
# Fold 1 Best | Epoch: 146 | Val Loss: 1.3456 | Macro F1: 0.3301 | Micro F1: 0.3550 | mAP: 0.3508 | Thr: 0.60
# Fold 2/5
# Epoch 01 | Train Loss: 1.2888 | Val Loss: 1.2271 | Macro F1: 0.1739 | Micro F1: 0.1943 | mAP: 0.1772 | Thr: 0.50
# Epoch 10 | Train Loss: 1.1408 | Val Loss: 1.1252 | Macro F1: 0.2444 | Micro F1: 0.2786 | mAP: 0.2696 | Thr: 0.60
# Epoch 20 | Train Loss: 1.0884 | Val Loss: 1.1036 | Macro F1: 0.2804 | Micro F1: 0.3031 | mAP: 0.2754 | Thr: 0.60
# Epoch 30 | Train Loss: 1.0442 | Val Loss: 1.2464 | Macro F1: 0.2404 | Micro F1: 0.1979 | mAP: 0.2802 | Thr: 0.45
# Epoch 40 | Train Loss: 1.0113 | Val Loss: 1.1301 | Macro F1: 0.2704 | Micro F1: 0.2564 | mAP: 0.2867 | Thr: 0.50
# Epoch 50 | Train Loss: 0.9640 | Val Loss: 1.2169 | Macro F1: 0.2735 | Micro F1: 0.2513 | mAP: 0.2824 | Thr: 0.55
# Epoch 60 | Train Loss: 0.9478 | Val Loss: 1.3206 | Macro F1: 0.2546 | Micro F1: 0.2065 | mAP: 0.2928 | Thr: 0.50
# Epoch 70 | Train Loss: 0.9561 | Val Loss: 1.1861 | Macro F1: 0.2798 | Micro F1: 0.3268 | mAP: 0.2918 | Thr: 0.65
# Epoch 80 | Train Loss: 0.9240 | Val Loss: 1.2264 | Macro F1: 0.2777 | Micro F1: 0.2831 | mAP: 0.2794 | Thr: 0.55
# Epoch 90 | Train Loss: 0.9016 | Val Loss: 1.2753 | Macro F1: 0.2747 | Micro F1: 0.2509 | mAP: 0.2899 | Thr: 0.50
# Epoch 100 | Train Loss: 0.8433 | Val Loss: 1.2887 | Macro F1: 0.2756 | Micro F1: 0.2734 | mAP: 0.2925 | Thr: 0.50
# Epoch 110 | Train Loss: 0.8331 | Val Loss: 1.3074 | Macro F1: 0.3020 | Micro F1: 0.2936 | mAP: 0.2996 | Thr: 0.60
# Epoch 120 | Train Loss: 0.7801 | Val Loss: 1.6073 | Macro F1: 0.2237 | Micro F1: 0.2105 | mAP: 0.2958 | Thr: 0.30
# Epoch 130 | Train Loss: 0.7522 | Val Loss: 1.4219 | Macro F1: 0.2847 | Micro F1: 0.3139 | mAP: 0.3047 | Thr: 0.55
# Epoch 140 | Train Loss: 0.7446 | Val Loss: 1.3367 | Macro F1: 0.2903 | Micro F1: 0.2850 | mAP: 0.3064 | Thr: 0.50
# Epoch 150 | Train Loss: 0.7087 | Val Loss: 1.4915 | Macro F1: 0.3147 | Micro F1: 0.3340 | mAP: 0.2932 | Thr: 0.60
# Fold 2 Best | Epoch: 143 | Val Loss: 1.3164 | Macro F1: 0.3219 | Micro F1: 0.3081 | mAP: 0.3056 | Thr: 0.50
# Fold 3/5
# Epoch 01 | Train Loss: 1.2926 | Val Loss: 1.3010 | Macro F1: 0.1735 | Micro F1: 0.1840 | mAP: 0.1907 | Thr: 0.50
# Epoch 10 | Train Loss: 1.1387 | Val Loss: 1.2692 | Macro F1: 0.2097 | Micro F1: 0.2079 | mAP: 0.2262 | Thr: 0.40
# Epoch 20 | Train Loss: 1.0578 | Val Loss: 1.2336 | Macro F1: 0.2593 | Micro F1: 0.2540 | mAP: 0.2407 | Thr: 0.55
# Epoch 30 | Train Loss: 1.0224 | Val Loss: 1.3761 | Macro F1: 0.2418 | Micro F1: 0.2198 | mAP: 0.2449 | Thr: 0.55
# Epoch 40 | Train Loss: 1.0099 | Val Loss: 1.2537 | Macro F1: 0.2667 | Micro F1: 0.2715 | mAP: 0.2470 | Thr: 0.55
# Epoch 50 | Train Loss: 0.9958 | Val Loss: 1.2964 | Macro F1: 0.2494 | Micro F1: 0.2307 | mAP: 0.2505 | Thr: 0.50
# Epoch 60 | Train Loss: 0.9192 | Val Loss: 1.2909 | Macro F1: 0.2901 | Micro F1: 0.2584 | mAP: 0.2675 | Thr: 0.55
# Epoch 70 | Train Loss: 0.8994 | Val Loss: 1.3813 | Macro F1: 0.2840 | Micro F1: 0.2720 | mAP: 0.2691 | Thr: 0.60
# Epoch 80 | Train Loss: 0.8808 | Val Loss: 1.8289 | Macro F1: 0.2194 | Micro F1: 0.1950 | mAP: 0.2692 | Thr: 0.35
# Epoch 90 | Train Loss: 0.8372 | Val Loss: 1.5037 | Macro F1: 0.2586 | Micro F1: 0.2425 | mAP: 0.2856 | Thr: 0.60
# Epoch 100 | Train Loss: 0.8079 | Val Loss: 1.5187 | Macro F1: 0.2877 | Micro F1: 0.2818 | mAP: 0.2917 | Thr: 0.55
# Epoch 110 | Train Loss: 0.8040 | Val Loss: 1.4371 | Macro F1: 0.3041 | Micro F1: 0.2834 | mAP: 0.2783 | Thr: 0.55
# Epoch 120 | Train Loss: 0.7434 | Val Loss: 1.5239 | Macro F1: 0.2594 | Micro F1: 0.2286 | mAP: 0.2916 | Thr: 0.40
# Epoch 130 | Train Loss: 0.7325 | Val Loss: 1.9532 | Macro F1: 0.2116 | Micro F1: 0.2182 | mAP: 0.2809 | Thr: 0.50
# Epoch 140 | Train Loss: 0.7134 | Val Loss: 2.1963 | Macro F1: 0.2283 | Micro F1: 0.2129 | mAP: 0.2949 | Thr: 0.35
# Epoch 150 | Train Loss: 0.6717 | Val Loss: 1.6948 | Macro F1: 0.3088 | Micro F1: 0.3105 | mAP: 0.3121 | Thr: 0.50
# Fold 3 Best | Epoch: 59 | Val Loss: 1.2352 | Macro F1: 0.3209 | Micro F1: 0.2935 | mAP: 0.2786 | Thr: 0.60
# Fold 4/5
# Epoch 01 | Train Loss: 1.3073 | Val Loss: 1.2450 | Macro F1: 0.1595 | Micro F1: 0.1677 | mAP: 0.1962 | Thr: 0.45
# Epoch 10 | Train Loss: 1.1391 | Val Loss: 1.1502 | Macro F1: 0.2626 | Micro F1: 0.2669 | mAP: 0.2802 | Thr: 0.55
# Epoch 20 | Train Loss: 1.0969 | Val Loss: 1.1276 | Macro F1: 0.3011 | Micro F1: 0.2928 | mAP: 0.2957 | Thr: 0.60
# Epoch 30 | Train Loss: 1.0708 | Val Loss: 1.2816 | Macro F1: 0.2372 | Micro F1: 0.1826 | mAP: 0.2963 | Thr: 0.35
# Epoch 40 | Train Loss: 1.0318 | Val Loss: 1.1640 | Macro F1: 0.2619 | Micro F1: 0.2251 | mAP: 0.3245 | Thr: 0.40
# Epoch 50 | Train Loss: 1.0038 | Val Loss: 1.1015 | Macro F1: 0.3205 | Micro F1: 0.3547 | mAP: 0.3261 | Thr: 0.65
# Epoch 60 | Train Loss: 0.9417 | Val Loss: 1.1549 | Macro F1: 0.3005 | Micro F1: 0.2847 | mAP: 0.3090 | Thr: 0.50
# Epoch 70 | Train Loss: 0.9548 | Val Loss: 1.1645 | Macro F1: 0.2965 | Micro F1: 0.2788 | mAP: 0.3264 | Thr: 0.55
# Epoch 80 | Train Loss: 0.8940 | Val Loss: 1.1566 | Macro F1: 0.3151 | Micro F1: 0.3113 | mAP: 0.3382 | Thr: 0.45
# Epoch 90 | Train Loss: 0.8580 | Val Loss: 1.9409 | Macro F1: 0.2006 | Micro F1: 0.1844 | mAP: 0.3269 | Thr: 0.40
# Epoch 100 | Train Loss: 0.8360 | Val Loss: 1.1835 | Macro F1: 0.3227 | Micro F1: 0.3480 | mAP: 0.3329 | Thr: 0.55
# Epoch 110 | Train Loss: 0.8269 | Val Loss: 1.3632 | Macro F1: 0.2891 | Micro F1: 0.2415 | mAP: 0.3382 | Thr: 0.30
# Epoch 120 | Train Loss: 0.7657 | Val Loss: 1.4784 | Macro F1: 0.2666 | Micro F1: 0.2726 | mAP: 0.3297 | Thr: 0.55
# Epoch 130 | Train Loss: 0.7469 | Val Loss: 1.7349 | Macro F1: 0.2482 | Micro F1: 0.2432 | mAP: 0.3525 | Thr: 0.35
# Epoch 140 | Train Loss: 0.7375 | Val Loss: 2.3355 | Macro F1: 0.2030 | Micro F1: 0.1960 | mAP: 0.3403 | Thr: 0.35
# Epoch 150 | Train Loss: 0.6745 | Val Loss: 1.3081 | Macro F1: 0.3331 | Micro F1: 0.3562 | mAP: 0.3446 | Thr: 0.70
# Fold 4 Best | Epoch: 115 | Val Loss: 1.1576 | Macro F1: 0.3587 | Micro F1: 0.3658 | mAP: 0.3409 | Thr: 0.60
# Fold 5/5
# Epoch 01 | Train Loss: 1.2984 | Val Loss: 1.3023 | Macro F1: 0.1660 | Micro F1: 0.1690 | mAP: 0.1650 | Thr: 0.40
# Epoch 10 | Train Loss: 1.1330 | Val Loss: 1.2313 | Macro F1: 0.2429 | Micro F1: 0.2661 | mAP: 0.2356 | Thr: 0.55
# Epoch 20 | Train Loss: 1.0766 | Val Loss: 1.2542 | Macro F1: 0.2483 | Micro F1: 0.2778 | mAP: 0.2565 | Thr: 0.55
# Epoch 30 | Train Loss: 1.0160 | Val Loss: 1.3269 | Macro F1: 0.2630 | Micro F1: 0.2705 | mAP: 0.2504 | Thr: 0.55
# Epoch 40 | Train Loss: 0.9755 | Val Loss: 1.2460 | Macro F1: 0.2753 | Micro F1: 0.2852 | mAP: 0.2819 | Thr: 0.60
# Epoch 50 | Train Loss: 0.9672 | Val Loss: 1.3381 | Macro F1: 0.2649 | Micro F1: 0.2787 | mAP: 0.2729 | Thr: 0.50
# Epoch 60 | Train Loss: 0.8932 | Val Loss: 1.3477 | Macro F1: 0.2891 | Micro F1: 0.2811 | mAP: 0.2781 | Thr: 0.50
# Epoch 70 | Train Loss: 0.8604 | Val Loss: 1.4408 | Macro F1: 0.2890 | Micro F1: 0.2765 | mAP: 0.2907 | Thr: 0.55
# Epoch 80 | Train Loss: 0.8538 | Val Loss: 1.5697 | Macro F1: 0.2483 | Micro F1: 0.2650 | mAP: 0.2706 | Thr: 0.40
# Epoch 90 | Train Loss: 0.8176 | Val Loss: 1.6107 | Macro F1: 0.2663 | Micro F1: 0.2625 | mAP: 0.2969 | Thr: 0.45
# Epoch 100 | Train Loss: 0.7880 | Val Loss: 1.6885 | Macro F1: 0.2683 | Micro F1: 0.2652 | mAP: 0.2756 | Thr: 0.45
# Epoch 110 | Train Loss: 0.8094 | Val Loss: 1.6652 | Macro F1: 0.2878 | Micro F1: 0.3145 | mAP: 0.2954 | Thr: 0.55
# Epoch 120 | Train Loss: 0.7566 | Val Loss: 1.5588 | Macro F1: 0.2907 | Micro F1: 0.3481 | mAP: 0.3038 | Thr: 0.60
# Epoch 130 | Train Loss: 0.7062 | Val Loss: 1.7496 | Macro F1: 0.2846 | Micro F1: 0.3263 | mAP: 0.2838 | Thr: 0.60
# Epoch 140 | Train Loss: 0.6779 | Val Loss: 1.9875 | Macro F1: 0.2823 | Micro F1: 0.2781 | mAP: 0.3119 | Thr: 0.45
# Epoch 150 | Train Loss: 0.6496 | Val Loss: 1.9934 | Macro F1: 0.2944 | Micro F1: 0.3633 | mAP: 0.3258 | Thr: 0.60
# Fold 5 Best | Epoch: 143 | Val Loss: 1.7287 | Macro F1: 0.3363 | Micro F1: 0.3414 | mAP: 0.3250 | Thr: 0.50
#
# CV Summary for Residual + GAP | Macro F1: 0.3336 +/- 0.0154 | Micro F1: 0.3328 +/- 0.0309 | mAP: 0.3202 +/- 0.0289 | Best Epoch(median): 143 | Best Thr(median): 0.60
#
# -------------------- Retrain on full train_val: Residual + GAP --------------------
# Epoch 01 | Train Loss: 1.2962
# Epoch 10 | Train Loss: 1.1060
# Epoch 20 | Train Loss: 1.0503
# Epoch 30 | Train Loss: 1.0109
# Epoch 40 | Train Loss: 0.9659
# Epoch 50 | Train Loss: 0.9384
# Epoch 60 | Train Loss: 0.8887
# Epoch 70 | Train Loss: 0.8636
# Epoch 80 | Train Loss: 0.8121
# Epoch 90 | Train Loss: 0.7901
# Epoch 100 | Train Loss: 0.7496
# Epoch 110 | Train Loss: 0.7146
# Epoch 120 | Train Loss: 0.6823
# Epoch 130 | Train Loss: 0.6926
# Epoch 140 | Train Loss: 0.6502
# Epoch 143 | Train Loss: 0.5966
# Test Result | Loss: 2.5424 | Macro F1: 0.1860 | Micro F1: 0.2196 | Precision: 0.2115 | Recall: 0.3108 | mAP: 0.2503 | Thr: 0.60
# Model saved to: C:\Users\KangjieLU\Pokemon_Project\model\residual_gap.pth
#
# ======================== Plain + GMP | 5-Fold CV ========================
# Fold 1/5
# Epoch 01 | Train Loss: 1.8349 | Val Loss: 1.2835 | Macro F1: 0.1537 | Micro F1: 0.1564 | mAP: 0.1492 | Thr: 0.45
# Epoch 10 | Train Loss: 1.3125 | Val Loss: 1.2554 | Macro F1: 0.1681 | Micro F1: 0.1741 | mAP: 0.2082 | Thr: 0.50
# Epoch 20 | Train Loss: 1.2348 | Val Loss: 1.2473 | Macro F1: 0.1997 | Micro F1: 0.2034 | mAP: 0.1806 | Thr: 0.50
# Epoch 30 | Train Loss: 1.1572 | Val Loss: 1.2573 | Macro F1: 0.1940 | Micro F1: 0.2254 | mAP: 0.2104 | Thr: 0.55
# Epoch 40 | Train Loss: 1.1412 | Val Loss: 1.2811 | Macro F1: 0.1993 | Micro F1: 0.1921 | mAP: 0.2349 | Thr: 0.45
# Epoch 50 | Train Loss: 1.0861 | Val Loss: 1.2135 | Macro F1: 0.2607 | Micro F1: 0.2401 | mAP: 0.2835 | Thr: 0.50
# Epoch 60 | Train Loss: 1.0652 | Val Loss: 1.2445 | Macro F1: 0.2308 | Micro F1: 0.2525 | mAP: 0.2771 | Thr: 0.55
# Epoch 70 | Train Loss: 1.0630 | Val Loss: 1.2634 | Macro F1: 0.2465 | Micro F1: 0.2322 | mAP: 0.2842 | Thr: 0.50
# Epoch 80 | Train Loss: 1.0340 | Val Loss: 1.2122 | Macro F1: 0.2686 | Micro F1: 0.2678 | mAP: 0.2583 | Thr: 0.55
# Epoch 90 | Train Loss: 1.0266 | Val Loss: 1.1916 | Macro F1: 0.2804 | Micro F1: 0.2925 | mAP: 0.2763 | Thr: 0.60
# Epoch 100 | Train Loss: 0.9663 | Val Loss: 1.2149 | Macro F1: 0.2631 | Micro F1: 0.2557 | mAP: 0.2857 | Thr: 0.50
# Epoch 110 | Train Loss: 0.9663 | Val Loss: 1.2037 | Macro F1: 0.2650 | Micro F1: 0.2954 | mAP: 0.2760 | Thr: 0.55
# Epoch 120 | Train Loss: 0.9230 | Val Loss: 1.2110 | Macro F1: 0.2745 | Micro F1: 0.3043 | mAP: 0.2761 | Thr: 0.65
# Epoch 130 | Train Loss: 1.0001 | Val Loss: 1.2426 | Macro F1: 0.2814 | Micro F1: 0.2920 | mAP: 0.2797 | Thr: 0.55
# Epoch 140 | Train Loss: 0.9141 | Val Loss: 1.2520 | Macro F1: 0.2897 | Micro F1: 0.3224 | mAP: 0.2834 | Thr: 0.70
# Epoch 150 | Train Loss: 0.8777 | Val Loss: 1.3118 | Macro F1: 0.2773 | Micro F1: 0.2940 | mAP: 0.2879 | Thr: 0.65
# Fold 1 Best | Epoch: 136 | Val Loss: 1.2631 | Macro F1: 0.2953 | Micro F1: 0.3171 | mAP: 0.2890 | Thr: 0.65
# Fold 2/5
# Epoch 01 | Train Loss: 1.7893 | Val Loss: 1.2508 | Macro F1: 0.1471 | Micro F1: 0.1497 | mAP: 0.1382 | Thr: 0.30
# Epoch 10 | Train Loss: 1.3159 | Val Loss: 1.2006 | Macro F1: 0.1773 | Micro F1: 0.1772 | mAP: 0.2034 | Thr: 0.50
# Epoch 20 | Train Loss: 1.2123 | Val Loss: 1.1657 | Macro F1: 0.2188 | Micro F1: 0.1931 | mAP: 0.2058 | Thr: 0.50
# Epoch 30 | Train Loss: 1.1465 | Val Loss: 1.1276 | Macro F1: 0.2259 | Micro F1: 0.2709 | mAP: 0.2274 | Thr: 0.55
# Epoch 40 | Train Loss: 1.1060 | Val Loss: 1.1258 | Macro F1: 0.2390 | Micro F1: 0.2460 | mAP: 0.2447 | Thr: 0.55
# Epoch 50 | Train Loss: 1.1079 | Val Loss: 1.1265 | Macro F1: 0.2578 | Micro F1: 0.2488 | mAP: 0.2274 | Thr: 0.55
# Epoch 60 | Train Loss: 1.0599 | Val Loss: 1.0959 | Macro F1: 0.2612 | Micro F1: 0.2766 | mAP: 0.2403 | Thr: 0.55
# Epoch 70 | Train Loss: 1.0565 | Val Loss: 1.0991 | Macro F1: 0.2602 | Micro F1: 0.2763 | mAP: 0.2356 | Thr: 0.60
# Epoch 80 | Train Loss: 1.0351 | Val Loss: 1.1111 | Macro F1: 0.2926 | Micro F1: 0.3074 | mAP: 0.2527 | Thr: 0.60
# Epoch 90 | Train Loss: 1.0252 | Val Loss: 1.1330 | Macro F1: 0.2436 | Micro F1: 0.2394 | mAP: 0.2461 | Thr: 0.50
# Epoch 100 | Train Loss: 0.9712 | Val Loss: 1.1275 | Macro F1: 0.2655 | Micro F1: 0.2769 | mAP: 0.2667 | Thr: 0.60
# Epoch 110 | Train Loss: 0.9367 | Val Loss: 1.1641 | Macro F1: 0.2652 | Micro F1: 0.3108 | mAP: 0.2707 | Thr: 0.65
# Epoch 120 | Train Loss: 0.9533 | Val Loss: 1.1490 | Macro F1: 0.2611 | Micro F1: 0.3077 | mAP: 0.2794 | Thr: 0.65
# Epoch 130 | Train Loss: 0.9118 | Val Loss: 1.1580 | Macro F1: 0.2496 | Micro F1: 0.2455 | mAP: 0.2601 | Thr: 0.45
# Epoch 140 | Train Loss: 0.9053 | Val Loss: 1.2014 | Macro F1: 0.2885 | Micro F1: 0.3084 | mAP: 0.2793 | Thr: 0.60
# Epoch 150 | Train Loss: 0.8661 | Val Loss: 1.2019 | Macro F1: 0.2895 | Micro F1: 0.2925 | mAP: 0.2879 | Thr: 0.55
# Fold 2 Best | Epoch: 139 | Val Loss: 1.1563 | Macro F1: 0.3019 | Micro F1: 0.3109 | mAP: 0.2966 | Thr: 0.65
# Fold 3/5
# Epoch 01 | Train Loss: 1.8285 | Val Loss: 1.3326 | Macro F1: 0.1569 | Micro F1: 0.1628 | mAP: 0.1361 | Thr: 0.45
# Epoch 10 | Train Loss: 1.2786 | Val Loss: 1.2635 | Macro F1: 0.1927 | Micro F1: 0.1965 | mAP: 0.2156 | Thr: 0.50
# Epoch 20 | Train Loss: 1.2379 | Val Loss: 1.3541 | Macro F1: 0.1895 | Micro F1: 0.1752 | mAP: 0.1924 | Thr: 0.30
# Epoch 30 | Train Loss: 1.1723 | Val Loss: 1.2690 | Macro F1: 0.2199 | Micro F1: 0.2121 | mAP: 0.2187 | Thr: 0.50
# Epoch 40 | Train Loss: 1.1209 | Val Loss: 1.2430 | Macro F1: 0.2509 | Micro F1: 0.2509 | mAP: 0.2334 | Thr: 0.55
# Epoch 50 | Train Loss: 1.1083 | Val Loss: 1.2234 | Macro F1: 0.2529 | Micro F1: 0.2480 | mAP: 0.2357 | Thr: 0.55
# Epoch 60 | Train Loss: 1.0834 | Val Loss: 1.2793 | Macro F1: 0.2294 | Micro F1: 0.2293 | mAP: 0.2207 | Thr: 0.55
# Epoch 70 | Train Loss: 1.0649 | Val Loss: 1.2283 | Macro F1: 0.2542 | Micro F1: 0.2419 | mAP: 0.2550 | Thr: 0.55
# Epoch 80 | Train Loss: 1.0452 | Val Loss: 1.2577 | Macro F1: 0.2450 | Micro F1: 0.2322 | mAP: 0.2542 | Thr: 0.50
# Epoch 90 | Train Loss: 0.9929 | Val Loss: 1.3094 | Macro F1: 0.2539 | Micro F1: 0.2410 | mAP: 0.2436 | Thr: 0.55
# Epoch 100 | Train Loss: 0.9425 | Val Loss: 1.2933 | Macro F1: 0.2548 | Micro F1: 0.2529 | mAP: 0.2615 | Thr: 0.50
# Epoch 110 | Train Loss: 0.9656 | Val Loss: 1.2856 | Macro F1: 0.2538 | Micro F1: 0.2768 | mAP: 0.2775 | Thr: 0.65
# Epoch 120 | Train Loss: 0.9160 | Val Loss: 1.3166 | Macro F1: 0.2735 | Micro F1: 0.2780 | mAP: 0.2707 | Thr: 0.60
# Epoch 130 | Train Loss: 0.8573 | Val Loss: 1.3665 | Macro F1: 0.2674 | Micro F1: 0.2758 | mAP: 0.2622 | Thr: 0.60
# Epoch 140 | Train Loss: 0.8887 | Val Loss: 1.3346 | Macro F1: 0.2667 | Micro F1: 0.2862 | mAP: 0.2805 | Thr: 0.65
# Epoch 150 | Train Loss: 0.8095 | Val Loss: 1.5550 | Macro F1: 0.2680 | Micro F1: 0.2382 | mAP: 0.2804 | Thr: 0.55
# Fold 3 Best | Epoch: 103 | Val Loss: 1.3142 | Macro F1: 0.2778 | Micro F1: 0.2634 | mAP: 0.2678 | Thr: 0.55
# Fold 4/5
# Epoch 01 | Train Loss: 1.7876 | Val Loss: 1.2909 | Macro F1: 0.1529 | Micro F1: 0.1583 | mAP: 0.1271 | Thr: 0.45
# Epoch 10 | Train Loss: 1.3111 | Val Loss: 1.2196 | Macro F1: 0.2015 | Micro F1: 0.1795 | mAP: 0.1981 | Thr: 0.50
# Epoch 20 | Train Loss: 1.2503 | Val Loss: 1.1787 | Macro F1: 0.2127 | Micro F1: 0.2008 | mAP: 0.2141 | Thr: 0.50
# Epoch 30 | Train Loss: 1.1933 | Val Loss: 1.1945 | Macro F1: 0.2133 | Micro F1: 0.2332 | mAP: 0.2179 | Thr: 0.55
# Epoch 40 | Train Loss: 1.1577 | Val Loss: 1.1637 | Macro F1: 0.2464 | Micro F1: 0.2526 | mAP: 0.2511 | Thr: 0.55
# Epoch 50 | Train Loss: 1.1494 | Val Loss: 1.1701 | Macro F1: 0.2529 | Micro F1: 0.2691 | mAP: 0.2676 | Thr: 0.55
# Epoch 60 | Train Loss: 1.1031 | Val Loss: 1.1395 | Macro F1: 0.2802 | Micro F1: 0.2929 | mAP: 0.2949 | Thr: 0.60
# Epoch 70 | Train Loss: 1.0961 | Val Loss: 1.1451 | Macro F1: 0.2737 | Micro F1: 0.2537 | mAP: 0.3004 | Thr: 0.55
# Epoch 80 | Train Loss: 1.0640 | Val Loss: 1.1524 | Macro F1: 0.2802 | Micro F1: 0.3248 | mAP: 0.3146 | Thr: 0.70
# Epoch 90 | Train Loss: 1.0777 | Val Loss: 1.1472 | Macro F1: 0.2782 | Micro F1: 0.2582 | mAP: 0.2849 | Thr: 0.55
# Epoch 100 | Train Loss: 1.0064 | Val Loss: 1.1322 | Macro F1: 0.2874 | Micro F1: 0.2951 | mAP: 0.3066 | Thr: 0.65
# Epoch 110 | Train Loss: 0.9731 | Val Loss: 1.1677 | Macro F1: 0.2968 | Micro F1: 0.2811 | mAP: 0.3161 | Thr: 0.60
# Epoch 120 | Train Loss: 0.9396 | Val Loss: 1.1593 | Macro F1: 0.3191 | Micro F1: 0.3421 | mAP: 0.3227 | Thr: 0.65
# Epoch 130 | Train Loss: 0.9555 | Val Loss: 1.1498 | Macro F1: 0.3317 | Micro F1: 0.3368 | mAP: 0.3217 | Thr: 0.65
# Epoch 140 | Train Loss: 0.9220 | Val Loss: 1.1227 | Macro F1: 0.3436 | Micro F1: 0.3457 | mAP: 0.3463 | Thr: 0.60
# Epoch 150 | Train Loss: 0.9119 | Val Loss: 1.2385 | Macro F1: 0.3107 | Micro F1: 0.3292 | mAP: 0.3152 | Thr: 0.70
# Fold 4 Best | Epoch: 147 | Val Loss: 1.1475 | Macro F1: 0.3474 | Micro F1: 0.3566 | mAP: 0.3525 | Thr: 0.60
# Fold 5/5
# Epoch 01 | Train Loss: 1.8179 | Val Loss: 1.3327 | Macro F1: 0.1605 | Micro F1: 0.1631 | mAP: 0.1291 | Thr: 0.40
# Epoch 10 | Train Loss: 1.2938 | Val Loss: 1.2398 | Macro F1: 0.2218 | Micro F1: 0.2237 | mAP: 0.2151 | Thr: 0.50
# Epoch 20 | Train Loss: 1.2373 | Val Loss: 1.2678 | Macro F1: 0.2109 | Micro F1: 0.2220 | mAP: 0.2217 | Thr: 0.50
# Epoch 30 | Train Loss: 1.1454 | Val Loss: 1.2728 | Macro F1: 0.2252 | Micro F1: 0.2025 | mAP: 0.2188 | Thr: 0.45
# Epoch 40 | Train Loss: 1.1377 | Val Loss: 1.1828 | Macro F1: 0.2495 | Micro F1: 0.2380 | mAP: 0.2432 | Thr: 0.45
# Epoch 50 | Train Loss: 1.0890 | Val Loss: 1.1925 | Macro F1: 0.2759 | Micro F1: 0.2641 | mAP: 0.2613 | Thr: 0.50
# Epoch 60 | Train Loss: 1.0860 | Val Loss: 1.1867 | Macro F1: 0.2591 | Micro F1: 0.2853 | mAP: 0.2832 | Thr: 0.55
# Epoch 70 | Train Loss: 1.0632 | Val Loss: 1.2201 | Macro F1: 0.2426 | Micro F1: 0.2531 | mAP: 0.2713 | Thr: 0.50
# Epoch 80 | Train Loss: 1.0423 | Val Loss: 1.2493 | Macro F1: 0.2529 | Micro F1: 0.2701 | mAP: 0.2785 | Thr: 0.55
# Epoch 90 | Train Loss: 1.0268 | Val Loss: 1.1854 | Macro F1: 0.2750 | Micro F1: 0.2846 | mAP: 0.2851 | Thr: 0.55
# Epoch 100 | Train Loss: 0.9571 | Val Loss: 1.2689 | Macro F1: 0.2773 | Micro F1: 0.3123 | mAP: 0.2825 | Thr: 0.60
# Epoch 110 | Train Loss: 0.9387 | Val Loss: 1.2878 | Macro F1: 0.2936 | Micro F1: 0.3041 | mAP: 0.2904 | Thr: 0.55
# Epoch 120 | Train Loss: 0.9219 | Val Loss: 1.2699 | Macro F1: 0.2908 | Micro F1: 0.3081 | mAP: 0.2988 | Thr: 0.55
# Epoch 130 | Train Loss: 0.8972 | Val Loss: 1.3463 | Macro F1: 0.2680 | Micro F1: 0.2840 | mAP: 0.2841 | Thr: 0.50
# Epoch 140 | Train Loss: 0.9096 | Val Loss: 1.3510 | Macro F1: 0.2662 | Micro F1: 0.2878 | mAP: 0.2935 | Thr: 0.55
# Epoch 150 | Train Loss: 0.8512 | Val Loss: 1.3781 | Macro F1: 0.2935 | Micro F1: 0.3018 | mAP: 0.3032 | Thr: 0.55
# Fold 5 Best | Epoch: 122 | Val Loss: 1.3004 | Macro F1: 0.3119 | Micro F1: 0.3309 | mAP: 0.2903 | Thr: 0.60
#
# CV Summary for Plain + GMP | Macro F1: 0.3069 +/- 0.0259 | Micro F1: 0.3158 +/- 0.0342 | mAP: 0.2992 +/- 0.0317 | Best Epoch(median): 136 | Best Thr(median): 0.60
#
# -------------------- Retrain on full train_val: Plain + GMP --------------------
# Epoch 01 | Train Loss: 1.7866
# Epoch 10 | Train Loss: 1.2720
# Epoch 20 | Train Loss: 1.1847
# Epoch 30 | Train Loss: 1.1581
# Epoch 40 | Train Loss: 1.0806
# Epoch 50 | Train Loss: 1.0712
# Epoch 60 | Train Loss: 1.0397
# Epoch 70 | Train Loss: 1.0133
# Epoch 80 | Train Loss: 0.9756
# Epoch 90 | Train Loss: 0.9395
# Epoch 100 | Train Loss: 0.9005
# Epoch 110 | Train Loss: 0.8721
# Epoch 120 | Train Loss: 0.8338
# Epoch 130 | Train Loss: 0.7849
# Epoch 136 | Train Loss: 0.7912
# Test Result | Loss: 1.3083 | Macro F1: 0.2759 | Micro F1: 0.2755 | Precision: 0.2171 | Recall: 0.4549 | mAP: 0.2838 | Thr: 0.60
# Model saved to: C:\Users\KangjieLU\Pokemon_Project\model\plain_gmp.pth
#
# ======================== Final Summary ========================
#     Experiment       CV Macro F1       CV Micro F1            CV mAP  Best Epoch  Best Threshold  Test Macro F1  Test Micro F1  Test Precision  Test Recall  Test mAP
#    Plain + GAP 0.3160 +/- 0.0144 0.3189 +/- 0.0216 0.3069 +/- 0.0287         141             0.6         0.2845         0.2810          0.2518       0.3903    0.2790
# Residual + GAP 0.3336 +/- 0.0154 0.3328 +/- 0.0309 0.3202 +/- 0.0289         143             0.6         0.1860         0.2196          0.2115       0.3108    0.2503
#    Plain + GMP 0.3069 +/- 0.0259 0.3158 +/- 0.0342 0.2992 +/- 0.0317         136             0.6         0.2759         0.2755          0.2171       0.4549    0.2838

# %%
def plot_main_results(summary_raw_df):
    x = np.arange(len(summary_raw_df))
    width = 0.35

    plt.figure(figsize=(8, 5))
    plt.bar(
        x - width / 2,
        summary_raw_df["cv_macro_mean"],
        width,
        yerr=summary_raw_df["cv_macro_std"],
        capsize=4,
        label="CV Macro F1",
        color="#4C72B0",
    )
    plt.bar(
        x + width / 2,
        summary_raw_df["test_macro_f1"],
        width,
        label="Test Macro F1",
        color="#DD8452",
    )

    plt.xticks(x, summary_raw_df["Experiment"], rotation=15)
    plt.ylabel("Score")
    plt.title("Overall Performance Comparison")
    plt.legend()
    plt.tight_layout()
    plt.savefig(FIG_DIR / "main_results.png", dpi=300, bbox_inches="tight")
    plt.show()

plot_main_results(summary_raw_df)

def plot_mean_curve(history_df, metric, ylabel, filename):
    grouped = (
        history_df.groupby(["experiment", "epoch"])[metric]
        .agg(["mean", "std"])
        .reset_index()
    )

    plt.figure(figsize=(8, 5))

    for exp in history_df["experiment"].unique():
        sub = grouped[grouped["experiment"] == exp]
        x = sub["epoch"].to_numpy()
        y = sub["mean"].to_numpy()
        s = sub["std"].fillna(0).to_numpy()

        plt.plot(x, y, linewidth=2, label=exp)
        plt.fill_between(x, y - s, y + s, alpha=0.15)

    plt.xlabel("Epoch")
    plt.ylabel(ylabel)
    plt.title(f"{ylabel} Across 5 CV Folds")
    plt.legend()
    plt.tight_layout()
    plt.savefig(FIG_DIR / filename, dpi=300, bbox_inches="tight")
    plt.show()

plot_mean_curve(history_df, "macro_f1", "Validation Macro F1", "val_macro_f1_curve.png")
plot_mean_curve(history_df, "val_loss", "Validation Loss", "val_loss_curve.png")

# %%
def plot_test_metrics(summary_raw_df):
    metrics = ["test_macro_f1", "test_micro_f1", "test_mAP"]
    labels = ["Macro F1", "Micro F1", "mAP"]

    x = np.arange(len(summary_raw_df))
    width = 0.25

    plt.figure(figsize=(9, 5))

    for i, (col, label) in enumerate(zip(metrics, labels)):
        plt.bar(
            x + (i - 1) * width,
            summary_raw_df[col],
            width,
            label=label,
        )

    plt.xticks(x, summary_raw_df["Experiment"], rotation=15)
    plt.ylabel("Score")
    plt.title("Test Metrics Comparison")
    plt.legend()
    plt.tight_layout()
    plt.savefig(FIG_DIR / "test_metrics.png", dpi=300, bbox_inches="tight")
    plt.show()

plot_test_metrics(summary_raw_df)

# %%
# --- 图 5：Test Precision vs Recall 对比图 ---
def plot_test_precision_recall(summary_raw_df):
    x = np.arange(len(summary_raw_df))
    width = 0.35

    plt.figure(figsize=(8, 5))
    plt.bar(
        x - width / 2,
        summary_raw_df["test_precision"],
        width,
        label="Test Precision",
        color="#55A868",
    )
    plt.bar(
        x + width / 2,
        summary_raw_df["test_recall"],
        width,
        label="Test Recall",
        color="#C44E52",
    )

    plt.xticks(x, summary_raw_df["Experiment"], rotation=15)
    plt.ylabel("Score")
    plt.title("Fig 5: Precision vs Recall on Held-out Test Set")
    plt.legend()
    plt.tight_layout()
    plt.savefig(FIG_DIR / "fig5_test_precision_recall.png", dpi=300, bbox_inches="tight")
    plt.show()


# --- 图 6：Per-Class F1 热力图 ---
def plot_test_class_f1_heatmap(summary_raw_df, class_names):
    matrix = np.vstack(summary_raw_df["test_class_f1"].values)

    plt.figure(figsize=(14, 4))
    sns.heatmap(
        matrix,
        annot=True,
        fmt=".2f",
        cmap="YlGnBu",
        xticklabels=class_names,
        yticklabels=summary_raw_df["Experiment"],
        cbar=True,
    )

    plt.title("Fig 6: Per-Class F1 Score on Held-out Test Set")
    plt.tight_layout()
    plt.savefig(FIG_DIR / "fig6_test_class_f1_heatmap.png", dpi=300, bbox_inches="tight")
    plt.show()


plot_test_precision_recall(summary_raw_df)
plot_test_class_f1_heatmap(summary_raw_df, class_names)

# %%
def package_current_experiment(exp_name=None, note=""):
    """
    将本次实验的所有产物封装到独立文件夹中。
    
    Parameters:
    -----------
    exp_name : str, optional
        实验名称，默认使用当前时间戳。
    note : str
        备注信息，会写入 config.txt 中。
    
    Returns:
    --------
    exp_dir : Path
        封装后的实验文件夹路径。
    """
    from pathlib import Path
    import pandas as pd
    
    # 创建实验根目录
    experiments_root = BASE_DIR / "experiments"
    experiments_root.mkdir(exist_ok=True)
    
    # 生成实验文件夹名
    if exp_name is None:
        timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
        exp_name = f"exp_{timestamp}_epoch{EPOCHS}_thr{THRESHOLDS[0]:.2f}_{THRESHOLDS[-1]:.2f}"
    exp_dir = experiments_root / exp_name
    exp_dir.mkdir(exist_ok=True)
    
    print(f"📦 正在封装实验到: {exp_dir}")
    
    # 1. 保存当前 notebook 副本
    notebook_src = Path.cwd() / "2_2.ipynb"
    if notebook_src.exists():
        shutil.copy2(notebook_src, exp_dir / "2_2.ipynb")
        print("   ✅ 已复制 notebook")
    
    # 2. 复制模型文件
    model_src_dir = MODEL_DIR
    model_dst_dir = exp_dir / "model"
    if model_src_dir.exists():
        shutil.copytree(model_src_dir, model_dst_dir, dirs_exist_ok=True)
        print("   ✅ 已复制模型文件")
    
    # 3. 复制图表
    fig_src_dir = FIG_DIR
    fig_dst_dir = exp_dir / "figures"
    if fig_src_dir.exists():
        shutil.copytree(fig_src_dir, fig_dst_dir, dirs_exist_ok=True)
        print("   ✅ 已复制图表")
    
    # 4. 保存汇总表格
    #    (需确保 summary_df, summary_raw_df, history_df 已在全局变量中)
    try:
        summary_df.to_csv(exp_dir / "summary_df.csv", index=False)
        summary_raw_df.to_csv(exp_dir / "summary_raw_df.csv", index=False)
        history_df.to_csv(exp_dir / "history_df.csv", index=False)
        print("   ✅ 已保存汇总表格")
    except NameError:
        print("   ⚠️ 未找到汇总表格变量，请先运行 main()")
    
    # 5. 保存实验配置信息
    config_info = {
        "experiment_name": exp_name,
        "timestamp": datetime.datetime.now().isoformat(),
        "note": note,
        "SEED": SEED,
        "TEST_RATIO": TEST_RATIO,
        "N_SPLITS": N_SPLITS,
        "BATCH_SIZE": BATCH_SIZE,
        "LR": LR,
        "EPOCHS": EPOCHS,
        "THRESHOLDS": THRESHOLDS.tolist() if isinstance(THRESHOLDS, np.ndarray) else THRESHOLDS,
        "SMOKE_TEST": SMOKE_TEST,
        "DEVICE": str(DEVICE),
    }
    with open(exp_dir / "config.json", "w") as f:
        json.dump(config_info, f, indent=2)
    print("   ✅ 已保存配置文件")
    
    print(f"\n✨ 实验封装完成！文件夹: {exp_dir}")
    return exp_dir

# %%
# 运行此单元格以封装本次实验结果
# 您可以在 note 参数中填写备注（例如 "baseline_epoch100"）
package_current_experiment(note="baseline_run")
# Out:
# 📦 正在封装实验到: C:\Users\KangjieLU\Pokemon_Project\experiments\exp_20260421_053617_epoch100_thr0.30_0.70
#    ✅ 已复制 notebook
#    ✅ 已复制模型文件
#    ✅ 已复制图表
#    ✅ 已保存汇总表格
#    ✅ 已保存配置文件
#
# ✨ 实验封装完成！文件夹: C:\Users\KangjieLU\Pokemon_Project\experiments\exp_20260421_053617_epoch100_thr0.30_0.70
# WindowsPath('C:/Users/KangjieLU/Pokemon_Project/experiments/exp_20260421_053617_epoch100_thr0.30_0.70')

# %%
def aggregate_experiments(experiments_root=None):
    """汇总所有实验的结果表格。"""
    if experiments_root is None:
        experiments_root = BASE_DIR / "experiments"
    
    all_raw_dfs = []
    for config_file in experiments_root.glob("*/config.json"):
        exp_dir = config_file.parent
        raw_csv = exp_dir / "summary_raw_df.csv"
        if not raw_csv.exists():
            continue
        
        df = pd.read_csv(raw_csv)
        # 添加实验标识列
        df.insert(0, "experiment_folder", exp_dir.name)
        
        # 读取配置信息并附加到每一行
        with open(config_file, "r") as f:
            config = json.load(f)
        for key in ["EPOCHS", "THRESHOLDS", "note"]:
            df[key] = str(config.get(key, ""))
        
        all_raw_dfs.append(df)
    
    if not all_raw_dfs:
        print("⚠️ 未找到任何实验数据。")
        return None
    
    combined = pd.concat(all_raw_dfs, ignore_index=True)
    # 按实验文件夹排序
    combined = combined.sort_values(["experiment_folder", "Experiment"])
    return combined

# 运行汇总
agg_df = aggregate_experiments()
if agg_df is not None:
    print("📊 所有实验结果汇总：")
    display(agg_df)
    
    # 可选：保存汇总表
    agg_df.to_csv(BASE_DIR / "experiments/all_experiments_summary.csv", index=False)
    print("✅ 汇总表已保存至 experiments/all_experiments_summary.csv")
